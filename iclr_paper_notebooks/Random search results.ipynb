# %%
import pandas as pd
import json

# %%
with open("../experiments/results_transe_wn11.json", "r") as f:
    r = json.load(f)
df = pd.DataFrame([{'model_name': i['model_name'], **i['model_params'], **i['results']} for i in r])
df.sort_values("mrr")
# Out:
#    batches_count embedding_model_params epochs eta    hits_1   hits_10  \
# 5            150                     {}   2000  25  0.001245  0.010373
# 44           150                     {}   2000  75  0.000830  0.010788
# 9             50                     {}   2000  75  0.004149  0.030705
# 20            50                     {}   2000  75  0.006224  0.044813
# 17            50                     {}   2000  25  0.001245  0.061826
# 36            50                     {}   2000  75  0.002490  0.077593
# 22           150                     {}   2000   5  0.002075  0.104149
# 29            50                     {}   2000  75  0.006639  0.108714
# 27            50                     {}   2000  25  0.017012  0.112448
# 30           100                     {}   2000  15  0.013693  0.118672
# 24           100                     {}   2000   5  0.011203  0.148548
# 8            100                     {}   2000  15  0.005394  0.178423
# ...

# %%
with open("../experiments/results_complex_wn11.json", "r") as f:
    r = json.load(f)
df = pd.DataFrame([{'model_name': i['model_name'], **i['model_params'], **i['results']} for i in r])
df.sort_values("mrr")
# Out:
#    batches_count embedding_model_params epochs eta    hits_1   hits_10  \
# 44           150                     {}   2000  75  0.000000  0.000000
# 22           150                     {}   2000   5  0.000000  0.000000
# 17            50                     {}   2000  25  0.000415  0.000830
# 20            50                     {}   2000  75  0.000830  0.001660
# 18           100                     {}   2000  75  0.004979  0.030290
# 5            150                     {}   2000  25  0.011203  0.036515
# 12            50                     {}   2000  25  0.016598  0.101245
# 0             50                     {}   2000  50  0.020747  0.091701
# 35           150                     {}   2000  50  0.031950  0.072199
# 39           100                     {}   2000  25  0.021162  0.093361
# 28           150                     {}   2000   5  0.029876  0.089627
# 4            100                     {}   2000  15  0.033195  0.103320
# ...

# %%
with open("../experiments/results_transe_fb13.json", "r") as f:
    r = json.load(f)
df = pd.DataFrame([{'model_name': i['model_name'], **i['model_params'], **i['results']} for i in r])
df.sort_values("mrr")
# Out:
#    batches_count embedding_model_params epochs eta    hits_1   hits_10  \
# 17            50                     {}   2000  25  0.031652  0.210054
# 36            50                     {}   2000  75  0.044008  0.270988
# 44           150                     {}   2000  75  0.103250  0.245430
# 22           150                     {}   2000   5  0.097664  0.255416
# 30           100                     {}   2000  15  0.098849  0.250169
# 5            150                     {}   2000  25  0.118653  0.265064
# 1            150                     {}   2000   5  0.134225  0.264387
# 28           150                     {}   2000   5  0.145396  0.266926
# 42           150                     {}   2000   5  0.143534  0.269465
# 31            50                     {}   2000  50  0.143026  0.270142
# 11            50                     {}   2000   5  0.144550  0.272850
# 32            50                     {}   2000  50  0.143703  0.273358
# ...

# %%
with open("../experiments/results_complex_fb13.json", "r") as f:
    r = json.load(f)
df = pd.DataFrame([{'model_name': i['model_name'], **i['model_params'], **i['results']} for i in r])
df.sort_values("mrr")
# Out:
#    batches_count embedding_model_params epochs eta  \
# 44           150                     {}   2000  75
# 20            50                     {}   2000  75
# 5            150                     {}   2000  25
# 17            50                     {}   2000  25
# 30           100                     {}   2000  15
# 31            50                     {}   2000  50
# 28           150                     {}   2000   5
# 46           150                     {}   2000  15
# 38            50                     {}   2000  75
# 35           150                     {}   2000  50
# 36            50                     {}   2000  75
# 11            50                     {}   2000   5
# 33           150                     {}   2000  50
# 6             50                     {}   2000  75
# 42           150                     {}   2000   5
# 43            50                     {}   2000  15
# 45            50                     {}   2000  15
# ...
